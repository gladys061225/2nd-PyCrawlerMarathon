# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11641344998","type":"CreateEvent","actor":{"id":19551954,"login":"Birskis-Barros","display_login":"Birskis-Barros","gravatar_id":"","url":"https://api.github.com/users/Birskis-Barros","avatar_url":"https://avatars.githubusercontent.com/u/19551954?"},"repo":{"id":243891116,"name":"Birskis-Barros/IBT-coevolution","url":"https://api.github.com/repos/Birskis-Barros/IBT-coevolution"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-02-29T02:29:43Z"},{"id":"11641344995","type":"IssueCommentEvent","actor":{"id":26384082,"login":"stale[bot]","display_login":"stale","gravatar_id":"","url":"https://api.github.com/users/stale[bot]","avatar_url":"https://avatars.githubusercontent.com/u/26384082?"},"repo":{"id":10744183,"name":"netdata/netdata","url":"https://api.github.com/repos/netdata/netdata"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/netdata/netdata/issues/7709","repository_url":"https://api.github.com/repos/netdata/netdata","labels_url":"https://api.github.com/repos/netdata/netdata/issues/7709/labels{/name}","comments_url":"https://api.github.com/repos/netdata/netdata/issues/7709/comments","events_url":"https://api.github.com/repos/netdata/netdata/issues/7709/events","html_url":"https://github.com/netdata/netdata/issues/7709","id":548527949,"node_id":"MDU6SXNzdWU1NDg1Mjc5NDk=","number":7709,"title":"I used the all in one installer. Can someone post step by step how to uninstall it","user":{"login":"lacedup","id":53834704,"node_id":"MDQ6VXNlcjUzODM0NzA0","avatar_url":"https://avatars0.githubusercontent.com/u/53834704?v=4","gravatar_id":"","url":"https://api.github.com/users/lacedup","html_url":"https://github.com/lacedup","followers_url":"https://api.github.com/users/lacedup/followers","following_url":"https://api.github.com/users/lacedup/following{/other_user}","gists_url":"https://api.github.com/users/lacedup/gists{/gist_id}","starred_url":"https://api.github.com/users/lacedup/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/lacedup/subscriptions","organizations_url":"https://api.github.com/users/lacedup/orgs","repos_url":"https://api.github.com/users/lacedup/repos","events_url":"https://api.github.com/users/lacedup/events{/privacy}","received_events_url":"https://api.github.com/users/lacedup/received_events","type":"User","site_admin":false},"labels":[{"id":1149989747,"node_id":"MDU6TGFiZWwxMTQ5OTg5NzQ3","url":"https://api.github.com/repos/netdata/netdata/labels/no%20changelog","name":"no changelog","color":"cccccc","default":false,"description":"Issues which are not going to be added to changelog"},{"id":43793264,"node_id":"MDU6TGFiZWw0Mzc5MzI2NA==","url":"https://api.github.com/repos/netdata/netdata/labels/question","name":"question","color":"cc317c","default":true,"description":null},{"id":1132073969,"node_id":"MDU6TGFiZWwxMTMyMDczOTY5","url":"https://api.github.com/repos/netdata/netdata/labels/stale","name":"stale","color":"cccccc","default":false,"description":""}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":3,"created_at":"2020-01-12T06:17:02Z","updated_at":"2020-02-29T02:29:43Z","closed_at":null,"author_association":"NONE","body":"I used the all in one installer. Can someone post step by step how to uninstall it? Thank you"},"comment":{"url":"https://api.github.com/repos/netdata/netdata/issues/comments/592822013","html_url":"https://github.com/netdata/netdata/issues/7709#issuecomment-592822013","issue_url":"https://api.github.com/repos/netdata/netdata/issues/7709","id":592822013,"node_id":"MDEyOklzc3VlQ29tbWVudDU5MjgyMjAxMw==","user":{"login":"stale[bot]","id":26384082,"node_id":"MDM6Qm90MjYzODQwODI=","avatar_url":"https://avatars3.githubusercontent.com/in/1724?v=4","gravatar_id":"","url":"https://api.github.com/users/stale%5Bbot%5D","html_url":"https://github.com/apps/stale","followers_url":"https://api.github.com/users ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11641344998',
#   'type': 'CreateEvent',
#   'actor': {'id': 19551954,
#    'login': 'Birskis-Barros',
#    'display_login': 'Birskis-Barros',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Birskis-Barros',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19551954?'},
#   'repo': {'id': 243891116,
#    'name': 'Birskis-Barros/IBT-coevolution',
#    'url': 'https://api.github.com/repos/Birskis-Barros/IBT-coevolution'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344995',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 26384082,
#    'login': 'stale[bot]',
#    'display_login': 'stale',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stale[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26384082?'},
#   'repo': {'id': 10744183,
#    'name': 'netdata/netdata',
#    'url': 'https://api.github.com/repos/netdata/netdata'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/netdata/netdata/issues/7709',
#     'repository_url': 'https://api.github.com/repos/netdata/netdata',
#     'labels_url': 'https://api.github.com/repos/netdata/netdata/issues/7709/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/netdata/netdata/issues/7709/comments',
#     'events_url': 'https://api.github.com/repos/netdata/netdata/issues/7709/events',
#     'html_url': 'https://github.com/netdata/netdata/issues/7709',
#     'id': 548527949,
#     'node_id': 'MDU6SXNzdWU1NDg1Mjc5NDk=',
#     'number': 7709,
#     'title': 'I used the all in one installer. Can someone post step by step how to uninstall it',
#     'user': {'login': 'lacedup',
#      'id': 53834704,
#      'node_id': 'MDQ6VXNlcjUzODM0NzA0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/53834704?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lacedup',
#      'html_url': 'https://github.com/lacedup',
#      'followers_url': 'https://api.github.com/users/lacedup/followers',
#      'following_url': 'https://api.github.com/users/lacedup/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lacedup/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lacedup/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lacedup/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lacedup/orgs',
#      'repos_url': 'https://api.github.com/users/lacedup/repos',
#      'events_url': 'https://api.github.com/users/lacedup/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lacedup/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1149989747,
#       'node_id': 'MDU6TGFiZWwxMTQ5OTg5NzQ3',
#       'url': 'https://api.github.com/repos/netdata/netdata/labels/no%20changelog',
#       'name': 'no changelog',
#       'color': 'cccccc',
#       'default': False,
#       'description': 'Issues which are not going to be added to changelog'},
#      {'id': 43793264,
#       'node_id': 'MDU6TGFiZWw0Mzc5MzI2NA==',
#       'url': 'https://api.github.com/repos/netdata/netdata/labels/question',
#       'name': 'question',
#       'color': 'cc317c',
#       'default': True,
#       'description': None},
#      {'id': 1132073969,
#       'node_id': 'MDU6TGFiZWwxMTMyMDczOTY5',
#       'url': 'https://api.github.com/repos/netdata/netdata/labels/stale',
#       'name': 'stale',
#       'color': 'cccccc',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-01-12T06:17:02Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'I used the all in one installer. Can someone post step by step how to uninstall it? Thank you'},
#    'comment': {'url': 'https://api.github.com/repos/netdata/netdata/issues/comments/592822013',
#     'html_url': 'https://github.com/netdata/netdata/issues/7709#issuecomment-592822013',
#     'issue_url': 'https://api.github.com/repos/netdata/netdata/issues/7709',
#     'id': 592822013,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjgyMjAxMw==',
#     'user': {'login': 'stale[bot]',
#      'id': 26384082,
#      'node_id': 'MDM6Qm90MjYzODQwODI=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/1724?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/stale%5Bbot%5D',
#      'html_url': 'https://github.com/apps/stale',
#      'followers_url': 'https://api.github.com/users/stale%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/stale%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/stale%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/stale%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/stale%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/stale%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/stale%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/stale%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/stale%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-02-29T02:29:43Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'author_association': 'NONE',
#     'body': 'This issue has been automatically closed due to extended period of inactivity. Please reopen if it is still valid. Thank you for your contributions.\n'}},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z',
#   'org': {'id': 43390781,
#    'login': 'netdata',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/netdata',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43390781?'}},
#  {'id': '11641344996',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 191058244,
#    'name': 'etorres11/splurty',
#    'url': 'https://api.github.com/repos/etorres11/splurty'},
#   'payload': {'ref': 'dependabot/bundler/puma-3.12.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344992',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 191238002,
#    'name': 'achadha2/graphQLdemo',
#    'url': 'https://api.github.com/repos/achadha2/graphQLdemo'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/3',
#     'repository_url': 'https://api.github.com/repos/achadha2/graphQLdemo',
#     'labels_url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/3/events',
#     'html_url': 'https://github.com/achadha2/graphQLdemo/pull/3',
#     'id': 533954346,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5OTM3NDU3',
#     'number': 3,
#     'title': 'Bump puma from 3.12.1 to 3.12.2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1649805265,
#       'node_id': 'MDU6TGFiZWwxNjQ5ODA1MjY1',
#       'url': 'https://api.github.com/repos/achadha2/graphQLdemo/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-06T12:51:23Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/achadha2/graphQLdemo/pulls/3',
#      'html_url': 'https://github.com/achadha2/graphQLdemo/pull/3',
#      'diff_url': 'https://github.com/achadha2/graphQLdemo/pull/3.diff',
#      'patch_url': 'https://github.com/achadha2/graphQLdemo/pull/3.patch'},
#     'body': "Bumps [puma](https://github.com/puma/puma) from 3.12.1 to 3.12.2.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [puma's changelog](https://github.com/puma/puma/blob/master/History.md).*\n\n> ## 4.3.1 and 3.12.2 / 2019-12-05\n> \n> * Security\n>   * Fix: a poorly-behaved client could use keepalive requests to monopolize Puma's reactor and create a denial of service attack. CVE-2019-16770.\n> \n> ## 4.3.0 / 2019-11-07\n> \n> * Features\n>   * Strip whitespace at end of HTTP headers ([#2010](https://github-redirect.dependabot.com/puma/puma/issues/2010))\n>   * Optimize HTTP parser for JRuby ([#2012](https://github-redirect.dependabot.com/puma/puma/issues/2012))\n>   * Add SSL support for the control app and cli ([#2046](https://github-redirect.dependabot.com/puma/puma/issues/2046), [#2052](https://github-redirect.dependabot.com/puma/puma/issues/2052))\n> \n> * Bugfixes\n>   * Fix Errno::EINVAL when SSL is enabled and browser rejects cert ([#1564](https://github-redirect.dependabot.com/puma/puma/issues/1564))\n>   * Fix pumactl defaulting puma to development if an environment was not specified ([#2035](https://github-redirect.dependabot.com/puma/puma/issues/2035))\n>   * Fix closing file stream when reading pid from pidfile ([#2048](https://github-redirect.dependabot.com/puma/puma/issues/2048))\n>   * Fix a typo in configuration option `--extra_runtime_dependencies` ([#2050](https://github-redirect.dependabot.com/puma/puma/issues/2050))\n> \n> ## 4.2.1 / 2019-10-07\n> \n> * 3 bugfixes\n>   * Fix socket activation of systemd (pre-existing) unix binder files ([#1842](https://github-redirect.dependabot.com/puma/puma/issues/1842), [#1988](https://github-redirect.dependabot.com/puma/puma/issues/1988))\n>   * Deal with multiple calls to bind correctly ([#1986](https://github-redirect.dependabot.com/puma/puma/issues/1986), [#1994](https://github-redirect.dependabot.com/puma/puma/issues/1994), [#2006](https://github-redirect.dependabot.com/puma/puma/issues/2006))\n>   * Accepts symbols for `verify_mode` ([#1222](https://github-redirect.dependabot.com/puma/puma/issues/1222))\n> \n> ## 4.2.0 / 2019-09-23\n> \n> * 6 features\n>   * Pumactl has a new -e environment option and reads `config/puma/<environment>.rb` config files ([#1885](https://github-redirect.dependabot.com/puma/puma/issues/1885))\n>   * Semicolons are now allowed in URL paths (MRI only), useful for Angular or Redmine ([#1934](https://github-redirect.dependabot.com/puma/puma/issues/1934))\n>   * Allow extra dependencies to be defined when using prune_bundler ([#1105](https://github-redirect.dependabot.com/puma/puma/issues/1105))\n>   * Puma now reports the correct port when binding to port 0, also reports other listeners when binding to localhost ([#1786](https://github-redirect.dependabot.com/puma/puma/issues/1786))\n>   * Sending SIGINFO to any Puma worker now prints currently active threads and their backtraces ([#1320](https://github-redirect.dependabot.com/puma/puma/issues/1320))\n>   * Puma threads all now have their name set on Ruby 2.3+ ([#1968](https://github-redirect.dependabot.com/puma/puma/issues/1968))\n> * 4 bugfixes\n>   * Fix some misbehavior with phased restart and externally SIGTERMed workers ([#1908](https://github-redirect.dependabot.com/puma/puma/issues/1908), [#1952](https://github-redirect.dependabot.com/puma/puma/issues/1952))\n>   * Fix socket closing on error ([#1941](https://github-redirect.dependabot.com/puma/puma/issues/1941))\n>   * Removed unnecessary SIGINT trap for JRuby that caused some race conditions ([#1961](https://github-redirect.dependabot.com/puma/puma/issues/1961))\n>   * Fix socket files being left around after process stopped ([#1970](https://github-redirect.dependabot.com/puma/puma/issues/1970))\n> * Absolutely thousands of lines of test improvements and fixes thanks to [@&#8203;MSP-Greg](https://github.com/MSP-Greg)\n> \n> ## 4.1.1 / 2019-09-05\n> \n> * 3 bugfixes\n>   * Revert our attempt to not dup STDOUT/ ...
#    'comment': {'url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/comments/592822012',
#     'html_url': 'https://github.com/achadha2/graphQLdemo/pull/3#issuecomment-592822012',
#     'issue_url': 'https://api.github.com/repos/achadha2/graphQLdemo/issues/3',
#     'id': 592822012,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjgyMjAxMg==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-02-29T02:29:43Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #6.'}},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344986',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 191393146,
#    'name': 'evsv/crash-dashboard',
#    'url': 'https://api.github.com/repos/evsv/crash-dashboard'},
#   'payload': {'ref': 'dependabot/bundler/puma-3.12.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A rails based app visualising crashes in Chicago',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344983',
#   'type': 'PushEvent',
#   'actor': {'id': 19982037,
#    'login': 'mcisback',
#    'display_login': 'mcisback',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcisback',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19982037?'},
#   'repo': {'id': 243650578,
#    'name': 'mcisback/miglioricuffiebluetooth-gatsby-netlify-cms',
#    'url': 'https://api.github.com/repos/mcisback/miglioricuffiebluetooth-gatsby-netlify-cms'},
#   'payload': {'push_id': 4698370822,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd467caa2cad5fd18a57001aa77af9d196024d587',
#    'before': '7e05d9cb6119b91b96bf79b5b2834187a377e0c2',
#    'commits': [{'sha': 'd467caa2cad5fd18a57001aa77af9d196024d587',
#      'author': {'email': 'mcisback@gmail.com', 'name': 'Marco Caggiano'},
#      'message': 'new logo 2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mcisback/miglioricuffiebluetooth-gatsby-netlify-cms/commits/d467caa2cad5fd18a57001aa77af9d196024d587'}]},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344988',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 191147415,
#    'name': 'ishrikanth/rails_angular_demo',
#    'url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo'},
#   'payload': {'action': 'opened',
#    'number': 8,
#    'pull_request': {'url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8',
#     'id': 381691445,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgxNjkxNDQ1',
#     'html_url': 'https://github.com/ishrikanth/rails_angular_demo/pull/8',
#     'diff_url': 'https://github.com/ishrikanth/rails_angular_demo/pull/8.diff',
#     'patch_url': 'https://github.com/ishrikanth/rails_angular_demo/pull/8.patch',
#     'issue_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/8',
#     'number': 8,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump puma from 3.12.1 to 3.12.3',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "Bumps [puma](https://github.com/puma/puma) from 3.12.1 to 3.12.3.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [puma's changelog](https://github.com/puma/puma/blob/master/History.md).*\n\n> ## 4.3.2 and 3.12.3 / 2020-02-27\n> \n> * Security\n>   * Fix: Prevent HTTP Response splitting via CR/LF in header values. CVE-2020-5247.\n> \n> ## 4.3.1 and 3.12.2 / 2019-12-05\n> \n> * Security\n>   * Fix: a poorly-behaved client could use keepalive requests to monopolize Puma's reactor and create a denial of service attack. CVE-2019-16770.\n> \n> ## 4.3.0 / 2019-11-07\n> \n> * Features\n>   * Strip whitespace at end of HTTP headers ([#2010](https://github-redirect.dependabot.com/puma/puma/issues/2010))\n>   * Optimize HTTP parser for JRuby ([#2012](https://github-redirect.dependabot.com/puma/puma/issues/2012))\n>   * Add SSL support for the control app and cli ([#2046](https://github-redirect.dependabot.com/puma/puma/issues/2046), [#2052](https://github-redirect.dependabot.com/puma/puma/issues/2052))\n> \n> * Bugfixes\n>   * Fix Errno::EINVAL when SSL is enabled and browser rejects cert ([#1564](https://github-redirect.dependabot.com/puma/puma/issues/1564))\n>   * Fix pumactl defaulting puma to development if an environment was not specified ([#2035](https://github-redirect.dependabot.com/puma/puma/issues/2035))\n>   * Fix closing file stream when reading pid from pidfile ([#2048](https://github-redirect.dependabot.com/puma/puma/issues/2048))\n>   * Fix a typo in configuration option `--extra_runtime_dependencies` ([#2050](https://github-redirect.dependabot.com/puma/puma/issues/2050))\n> \n> ## 4.2.1 / 2019-10-07\n> \n> * 3 bugfixes\n>   * Fix socket activation of systemd (pre-existing) unix binder files ([#1842](https://github-redirect.dependabot.com/puma/puma/issues/1842), [#1988](https://github-redirect.dependabot.com/puma/puma/issues/1988))\n>   * Deal with multiple calls to bind correctly ([#1986](https://github-redirect.dependabot.com/puma/puma/issues/1986), [#1994](https://github-redirect.dependabot.com/puma/puma/issues/1994), [#2006](https://github-redirect.dependabot.com/puma/puma/issues/2006))\n>   * Accepts symbols for `verify_mode` ([#1222](https://github-redirect.dependabot.com/puma/puma/issues/1222))\n> \n> ## 4.2.0 / 2019-09-23\n> \n> * 6 features\n>   * Pumactl has a new -e environment option and reads `config/puma/<environment>.rb` config files ([#1885](https://github-redirect.dependabot.com/puma/puma/issues/1885))\n>   * Semicolons are now allowed in URL paths (MRI only), useful for Angular or Redmine ([#1934](https://github-redirect.dependabot.com/puma/puma/issues/1934))\n>   * Allow extra dependencies to be defined when using prune_bundler ([#1105](https://github-redirect.dependabot.com/puma/puma/issues/1105))\n>   * Puma now reports the correct port when binding to port 0, also reports other listeners when binding to localhost ([#1786](https://github-redirect.dependabot.com/puma/puma/issues/1786))\n>   * Sending SIGINFO to any Puma worker now prints currently active threads and their backtraces ([#1320](https://github-redirect.dependabot.com/puma/puma/issues/1320))\n>   * Puma threads all now have their name set on Ruby 2.3+ ([#1968](https://github-redirect.dependabot.com/puma/puma/issues/1968))\n> * 4 bugfixes\n>   * Fix some misbehavior with phased restart and externally SIGTERMed workers ([#1908](https://github-redirect.dependabot.com/puma/puma/issues/1908), [#1952](https://github-redirect.dependabot.com/puma/puma/issues/1952))\n>   * Fix socket closing on error ([#1941](https://github-redirect.dependabot.com/puma/puma/issues/1941))\n>   * Removed unnecessary SIGINT trap for JRuby that caused some race conditions ([#1961](https://github-redirect.dependabot.com/puma/puma/issues/1961))\n>   * Fix socket files being left around after process stopped ([#1970](https://github-redirect.dependabot.com/puma/puma/issues/1970))\n> * Absolutely thousands of lines of test improvements and fixes thanks ...
#     'created_at': '2020-02-29T02:29:42Z',
#     'updated_at': '2020-02-29T02:29:42Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8/commits',
#     'review_comments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8/comments',
#     'review_comment_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/8/comments',
#     'statuses_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/statuses/361fe972ec2ac0200077a0f9562ceebc75022276',
#     'head': {'label': 'ishrikanth:dependabot/bundler/puma-3.12.3',
#      'ref': 'dependabot/bundler/puma-3.12.3',
#      'sha': '361fe972ec2ac0200077a0f9562ceebc75022276',
#      'user': {'login': 'ishrikanth',
#       'id': 820143,
#       'node_id': 'MDQ6VXNlcjgyMDE0Mw==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/820143?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ishrikanth',
#       'html_url': 'https://github.com/ishrikanth',
#       'followers_url': 'https://api.github.com/users/ishrikanth/followers',
#       'following_url': 'https://api.github.com/users/ishrikanth/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ishrikanth/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ishrikanth/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ishrikanth/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ishrikanth/orgs',
#       'repos_url': 'https://api.github.com/users/ishrikanth/repos',
#       'events_url': 'https://api.github.com/users/ishrikanth/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ishrikanth/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 191147415,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTExNDc0MTU=',
#       'name': 'rails_angular_demo',
#       'full_name': 'ishrikanth/rails_angular_demo',
#       'private': False,
#       'owner': {'login': 'ishrikanth',
#        'id': 820143,
#        'node_id': 'MDQ6VXNlcjgyMDE0Mw==',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/820143?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ishrikanth',
#        'html_url': 'https://github.com/ishrikanth',
#        'followers_url': 'https://api.github.com/users/ishrikanth/followers',
#        'following_url': 'https://api.github.com/users/ishrikanth/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ishrikanth/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ishrikanth/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ishrikanth/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ishrikanth/orgs',
#        'repos_url': 'https://api.github.com/users/ishrikanth/repos',
#        'events_url': 'https://api.github.com/users/ishrikanth/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ishrikanth/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ishrikanth/rails_angular_demo',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo',
#       'forks_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/forks',
#       'keys_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/teams',
#       'hooks_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/events',
#       'assignees_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/tags',
#       'blobs_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/languages',
#       'stargazers_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/subscription',
#       'commits_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/merges',
#       'archive_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/downloads',
#       'issues_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/deployments',
#       'created_at': '2019-06-10T10:32:53Z',
#       'updated_at': '2019-06-27T13:48:47Z',
#       'pushed_at': '2020-02-29T02:29:42Z',
#       'git_url': 'git://github.com/ishrikanth/rails_angular_demo.git',
#       'ssh_url': 'git@github.com:ishrikanth/rails_angular_demo.git',
#       'clone_url': 'https://github.com/ishrikanth/rails_angular_demo.git',
#       'svn_url': 'https://github.com/ishrikanth/rails_angular_demo',
#       'homepage': None,
#       'size': 315,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': None,
#       'forks': 0,
#       'open_issues': 8,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ishrikanth:master',
#      'ref': 'master',
#      'sha': '1e1b23b9c5b6f21d5ec1ab9b95f9bf482d447c3b',
#      'user': {'login': 'ishrikanth',
#       'id': 820143,
#       'node_id': 'MDQ6VXNlcjgyMDE0Mw==',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/820143?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ishrikanth',
#       'html_url': 'https://github.com/ishrikanth',
#       'followers_url': 'https://api.github.com/users/ishrikanth/followers',
#       'following_url': 'https://api.github.com/users/ishrikanth/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ishrikanth/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ishrikanth/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ishrikanth/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ishrikanth/orgs',
#       'repos_url': 'https://api.github.com/users/ishrikanth/repos',
#       'events_url': 'https://api.github.com/users/ishrikanth/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ishrikanth/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 191147415,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTExNDc0MTU=',
#       'name': 'rails_angular_demo',
#       'full_name': 'ishrikanth/rails_angular_demo',
#       'private': False,
#       'owner': {'login': 'ishrikanth',
#        'id': 820143,
#        'node_id': 'MDQ6VXNlcjgyMDE0Mw==',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/820143?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ishrikanth',
#        'html_url': 'https://github.com/ishrikanth',
#        'followers_url': 'https://api.github.com/users/ishrikanth/followers',
#        'following_url': 'https://api.github.com/users/ishrikanth/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ishrikanth/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ishrikanth/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ishrikanth/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ishrikanth/orgs',
#        'repos_url': 'https://api.github.com/users/ishrikanth/repos',
#        'events_url': 'https://api.github.com/users/ishrikanth/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ishrikanth/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ishrikanth/rails_angular_demo',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo',
#       'forks_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/forks',
#       'keys_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/teams',
#       'hooks_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/events',
#       'assignees_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/tags',
#       'blobs_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/languages',
#       'stargazers_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/subscription',
#       'commits_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/merges',
#       'archive_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/downloads',
#       'issues_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/deployments',
#       'created_at': '2019-06-10T10:32:53Z',
#       'updated_at': '2019-06-27T13:48:47Z',
#       'pushed_at': '2020-02-29T02:29:42Z',
#       'git_url': 'git://github.com/ishrikanth/rails_angular_demo.git',
#       'ssh_url': 'git@github.com:ishrikanth/rails_angular_demo.git',
#       'clone_url': 'https://github.com/ishrikanth/rails_angular_demo.git',
#       'svn_url': 'https://github.com/ishrikanth/rails_angular_demo',
#       'homepage': None,
#       'size': 315,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': None,
#       'forks': 0,
#       'open_issues': 8,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8'},
#      'html': {'href': 'https://github.com/ishrikanth/rails_angular_demo/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ishrikanth/rails_angular_demo/statuses/361fe972ec2ac0200077a0f9562ceebc75022276'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344984',
#   'type': 'CreateEvent',
#   'actor': {'id': 11627963,
#    'login': 'smallo92',
#    'display_login': 'smallo92',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smallo92',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11627963?'},
#   'repo': {'id': 243891110,
#    'name': 'smallo92/xnNightclub',
#    'url': 'https://api.github.com/repos/smallo92/xnNightclub'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Nightclub in Vespucci with NPCs',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344980',
#   'type': 'PushEvent',
#   'actor': {'id': 22182446,
#    'login': 'plantprogrammer',
#    'display_login': 'plantprogrammer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/plantprogrammer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22182446?'},
#   'repo': {'id': 243890348,
#    'name': 'plantprogrammer/webinfo',
#    'url': 'https://api.github.com/repos/plantprogrammer/webinfo'},
#   'payload': {'push_id': 4698370818,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '852c09bf435aa8cb052f0db2fef187f90b65900c',
#    'before': 'd6fc0876cfd3989e227b752c0389be6b83e81a16',
#    'commits': [{'sha': '852c09bf435aa8cb052f0db2fef187f90b65900c',
#      'author': {'email': 'ian.sajkowicz@uconn.edu', 'name': 'Ian'},
#      'message': 'Create manifest.json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/plantprogrammer/webinfo/commits/852c09bf435aa8cb052f0db2fef187f90b65900c'}]},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344978',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 152944138,
#    'name': 'EndemolShineGroup/cz-github',
#    'url': 'https://api.github.com/repos/EndemolShineGroup/cz-github'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/14',
#     'repository_url': 'https://api.github.com/repos/EndemolShineGroup/cz-github',
#     'labels_url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/14/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/14/comments',
#     'events_url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/14/events',
#     'html_url': 'https://github.com/EndemolShineGroup/cz-github/pull/14',
#     'id': 395468614,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjQxOTE0MDg1',
#     'number': 14,
#     'title': 'Update typedoc to the latest version 🚀',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1090901024,
#       'node_id': 'MDU6TGFiZWwxMDkwOTAxMDI0',
#       'url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/labels/greenkeeper',
#       'name': 'greenkeeper',
#       'color': '00c775',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 20,
#     'created_at': '2019-01-03T06:26:32Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/pulls/14',
#      'html_url': 'https://github.com/EndemolShineGroup/cz-github/pull/14',
#      'diff_url': 'https://github.com/EndemolShineGroup/cz-github/pull/14.diff',
#      'patch_url': 'https://github.com/EndemolShineGroup/cz-github/pull/14.patch'},
#     'body': '\n## The devDependency [typedoc](https://github.com/TypeStrong/TypeDoc) was updated from `0.13.0` to `0.14.0`.\nThis version is **not covered** by your **current version range**.\n\nIf you don’t accept this pull request, your project will work just like it did before. However, you might be missing out on a bunch of new features, fixes and/or performance improvements from the dependency update.\n\n---\n\n[Find out more about this release](https://github.com/TypeStrong/TypeDoc).\n\n<details>\n  <summary>FAQ and help</summary>\n\n  There is a collection of [frequently asked questions](https://greenkeeper.io/faq.html). If those don’t help, you can always [ask the humans behind Greenkeeper](https://github.com/greenkeeperio/greenkeeper/issues/new).\n</details>\n\n---\n\n\nYour [Greenkeeper](https://greenkeeper.io) bot :palm_tree:\n\n'},
#    'comment': {'url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/comments/592822011',
#     'html_url': 'https://github.com/EndemolShineGroup/cz-github/pull/14#issuecomment-592822011',
#     'issue_url': 'https://api.github.com/repos/EndemolShineGroup/cz-github/issues/14',
#     'id': 592822011,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjgyMjAxMQ==',
#     'user': {'login': 'greenkeeper[bot]',
#      'id': 23040076,
#      'node_id': 'MDM6Qm90MjMwNDAwNzY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/505?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/greenkeeper%5Bbot%5D',
#      'html_url': 'https://github.com/apps/greenkeeper',
#      'followers_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/greenkeeper%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-02-29T02:29:43Z',
#     'updated_at': '2020-02-29T02:29:43Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '- The `devDependency` [typedoc](https://github.com/TypeStrong/TypeDoc) was updated from `0.13.0` to `0.16.11`.\n\n[Update to this version instead 🚀](https://github.com/EndemolShineGroup/cz-github/compare/develop...EndemolShineGroup:greenkeeper%2Ftypedoc-0.16.11)'}},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z',
#   'org': {'id': 9568512,
#    'login': 'EndemolShineGroup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/EndemolShineGroup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9568512?'}},
#  {'id': '11641344976',
#   'type': 'MemberEvent',
# ...
#       'repos_url': 'https://api.github.com/users/kubernetes/repos',
#       'events_url': 'https://api.github.com/users/kubernetes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kubernetes/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 57333709,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk1NzMzMzcwOQ==',
#       'name': 'test-infra',
#       'full_name': 'kubernetes/test-infra',
#       'private': False,
#       'owner': {'login': 'kubernetes',
#        'id': 13629408,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNjI5NDA4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/13629408?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kubernetes',
#        'html_url': 'https://github.com/kubernetes',
#        'followers_url': 'https://api.github.com/users/kubernetes/followers',
#        'following_url': 'https://api.github.com/users/kubernetes/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kubernetes/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kubernetes/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kubernetes/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kubernetes/orgs',
#        'repos_url': 'https://api.github.com/users/kubernetes/repos',
#        'events_url': 'https://api.github.com/users/kubernetes/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kubernetes/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kubernetes/test-infra',
#       'description': 'Test infrastructure for the Kubernetes project.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kubernetes/test-infra',
#       'forks_url': 'https://api.github.com/repos/kubernetes/test-infra/forks',
#       'keys_url': 'https://api.github.com/repos/kubernetes/test-infra/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kubernetes/test-infra/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kubernetes/test-infra/teams',
#       'hooks_url': 'https://api.github.com/repos/kubernetes/test-infra/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kubernetes/test-infra/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kubernetes/test-infra/events',
#       'assignees_url': 'https://api.github.com/repos/kubernetes/test-infra/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kubernetes/test-infra/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kubernetes/test-infra/tags',
#       'blobs_url': 'https://api.github.com/repos/kubernetes/test-infra/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kubernetes/test-infra/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kubernetes/test-infra/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kubernetes/test-infra/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kubernetes/test-infra/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kubernetes/test-infra/languages',
#       'stargazers_url': 'https://api.github.com/repos/kubernetes/test-infra/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kubernetes/test-infra/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kubernetes/test-infra/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kubernetes/test-infra/subscription',
#       'commits_url': 'https://api.github.com/repos/kubernetes/test-infra/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kubernetes/test-infra/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kubernetes/test-infra/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kubernetes/test-infra/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kubernetes/test-infra/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kubernetes/test-infra/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kubernetes/test-infra/merges',
#       'archive_url': 'https://api.github.com/repos/kubernetes/test-infra/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kubernetes/test-infra/downloads',
#       'issues_url': 'https://api.github.com/repos/kubernetes/test-infra/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kubernetes/test-infra/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kubernetes/test-infra/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kubernetes/test-infra/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kubernetes/test-infra/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kubernetes/test-infra/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kubernetes/test-infra/deployments',
#       'created_at': '2016-04-28T21:05:35Z',
#       'updated_at': '2020-02-29T02:16:40Z',
#       'pushed_at': '2020-02-29T02:06:40Z',
#       'git_url': 'git://github.com/kubernetes/test-infra.git',
#       'ssh_url': 'git@github.com:kubernetes/test-infra.git',
#       'clone_url': 'https://github.com/kubernetes/test-infra.git',
#       'svn_url': 'https://github.com/kubernetes/test-infra',
#       'homepage': None,
#       'size': 112687,
#       'stargazers_count': 1919,
#       'watchers_count': 1919,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 1297,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 354,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 1297,
#       'open_issues': 354,
#       'watchers': 1919,
#       'default_branch': 'master'}},
#     'base': {'label': 'michal-hudy:master',
#      'ref': 'master',
#      'sha': '09f5a51c86ec159e06abdc9a78af7855f202fa60',
#      'user': {'login': 'michal-hudy',
#       'id': 26445970,
#       'node_id': 'MDQ6VXNlcjI2NDQ1OTcw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/26445970?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/michal-hudy',
#       'html_url': 'https://github.com/michal-hudy',
#       'followers_url': 'https://api.github.com/users/michal-hudy/followers',
#       'following_url': 'https://api.github.com/users/michal-hudy/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/michal-hudy/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/michal-hudy/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/michal-hudy/subscriptions',
#       'organizations_url': 'https://api.github.com/users/michal-hudy/orgs',
#       'repos_url': 'https://api.github.com/users/michal-hudy/repos',
#       'events_url': 'https://api.github.com/users/michal-hudy/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/michal-hudy/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 214623679,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTQ2MjM2Nzk=',
#       'name': 'k8s-test-infra',
#       'full_name': 'michal-hudy/k8s-test-infra',
#       'private': False,
#       'owner': {'login': 'michal-hudy',
#        'id': 26445970,
#        'node_id': 'MDQ6VXNlcjI2NDQ1OTcw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/26445970?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/michal-hudy',
#        'html_url': 'https://github.com/michal-hudy',
#        'followers_url': 'https://api.github.com/users/michal-hudy/followers',
#        'following_url': 'https://api.github.com/users/michal-hudy/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/michal-hudy/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/michal-hudy/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/michal-hudy/subscriptions',
#        'organizations_url': 'https://api.github.com/users/michal-hudy/orgs',
#        'repos_url': 'https://api.github.com/users/michal-hudy/repos',
#        'events_url': 'https://api.github.com/users/michal-hudy/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/michal-hudy/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/michal-hudy/k8s-test-infra',
#       'description': 'Test infrastructure for the Kubernetes project.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra',
#       'forks_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/forks',
#       'keys_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/teams',
#       'hooks_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/hooks',
#       'issue_events_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/events',
#       'assignees_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/tags',
#       'blobs_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/languages',
#       'stargazers_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/stargazers',
#       'contributors_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/contributors',
#       'subscribers_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/subscribers',
#       'subscription_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/subscription',
#       'commits_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/merges',
#       'archive_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/downloads',
#       'issues_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/deployments',
#       'created_at': '2019-10-12T09:59:50Z',
#       'updated_at': '2020-02-29T00:31:26Z',
#       'pushed_at': '2020-02-29T00:31:24Z',
#       'git_url': 'git://github.com/michal-hudy/k8s-test-infra.git',
#       'ssh_url': 'git@github.com:michal-hudy/k8s-test-infra.git',
#       'clone_url': 'https://github.com/michal-hudy/k8s-test-infra.git',
#       'svn_url': 'https://github.com/michal-hudy/k8s-test-infra',
#       'homepage': None,
#       'size': 111891,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/pulls/922'},
#      'html': {'href': 'https://github.com/michal-hudy/k8s-test-infra/pull/922'},
#      'issue': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/issues/922'},
#      'comments': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/issues/922/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/pulls/922/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/pulls/922/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/michal-hudy/k8s-test-infra/statuses/c9afdd2f5c65c6f6b9fb0c0735381bbab6f07039'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 5,
#     'deletions': 5,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344938',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 191139454,
#    'name': 'automateict/vetis',
#    'url': 'https://api.github.com/repos/automateict/vetis'},
#   'payload': {'ref': 'dependabot/bundler/puma-3.12.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'},
#  {'id': '11641344937',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10956186,
#    'login': 'mzaglia',
#    'display_login': 'mzaglia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mzaglia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10956186?'},
#   'repo': {'id': 192073985,
#    'name': 'mzaglia/bdc-stac',
#    'url': 'https://api.github.com/repos/mzaglia/bdc-stac'},
#   'payload': {'ref': 'wip', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-29T02:29:43Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
practice = requests.get("https://cat-fact.herokuapp.com/facts")

practice.text
# Out:
# '{"all":[{"_id":"58e008ad0aac31001185ed0c","text":"The frequency of a domestic cat\'s purr is the same at which muscles and bones repair themselves.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":10,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":6,"userUpvoted":null},{"_id":"599f89639a11040c4a163440","text":"Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"59951d5ef2db18002031693c","text":"America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b01a447c6914f0014cc9a30","text":"The special sensory organ called the Jacobson\'s organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat\'s nasal cavity and is located on the roof of their mouth behind their teeth.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b4055841d9700146158d3","text":"Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","text":"Most cats don\'t like water because their coats do not insulate them well enough.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5a4d76916ef087002174c28b","text":"A cat’s n ...

# %%
practice2 = requests.get("https://bnb.data.bl.uk/")

practice2.text
# Out:
# '<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\n<!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><!--<![endif]-->\n\n<head>\n  <meta charset="utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="canonical" href="/home" />\n<link rel="shortlink" href="/node/25" />\n<link rel="shortcut icon" href="https://bnb.data.bl.uk/sites/all/themes/britishlibrary/favicon.ico" type="image/vnd.microsoft.icon" />\n  <title>Welcome to bnb.data.bl.uk | The British National Bibliography</title>\n\n      <meta name="MobileOptimized" content="width">\n    <meta name="HandheldFriendly" content="true">\n    <meta name="viewport" content="width=device-width">\n    <!--[if IEMobile]><meta http-equiv="cleartype" content="on"><![endif]-->\n\n  <link type="text/css" rel="stylesheet" href="https://bnb.data.bl.uk/sites/default/files/css/css_kShW4RPmRstZ3SpIC-ZvVGNFVAi0WEMuCnI0ZkYIaFw.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://bnb.data.bl.uk/sites/default/files/css/css_mxbvRAV0_YoXwGCXbsQzCkegc1pXHICzfd8PPQD9YE4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://bnb.data.bl.uk/sites/default/files/css/css_ONUirtjNp1W5GCRMF__E1LgAIJE8wlynmmsy7-uCaE8.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://bnb.data.bl.uk/sites/default/files/css/css_p6mpfGyQfg44Sh_OybfVqX1p33gpgSK2o4g9jFnoark.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://bnb.data.bl.uk/sites/default/files/css/css_HJmQo8Rmxq8Mq3geSmHdaY_qIUM64yGupyO8-tCHAgk.css" media="all" />\n  <script src="https://bnb.data.bl.uk/sites/all/modules/jquery_update/replace/jquery/1.5/jquery.min.js?v=1.5.2"></script>\n<script src="https://bnb.data.bl.uk/misc/jquery-extend-3.4.0.js?v=1.5.2"></script>\n<script src="https://bnb.data.bl.uk/misc/jquery.once.js?v=1.2"></script>\n<script src="https://bnb.data.bl.uk/misc/drupal.js?pvz0k7"></script>\n<script src="https://bnb.data.bl.uk/misc/ui/jquery.ui.core.min.js?v=1.8.7"></script>\n<script src="https://bnb.data.bl.uk/misc/ui/jquery.ui.widget.min.js?v=1.8.7"></script>\n<script src="https://bnb.data.bl.uk/misc/ui/jquery.ui.position.min.js?v=1.8.7"></script>\n<script src="https://bnb.data.bl.uk/misc/ui/jquery.ui.autocomplete.min.js?v=1.8.7"></script>\n<script src="https://bnb.data.bl.uk/sites/all/themes/britishlibrary/js/solr-search.js?pvz0k7"></script>\n<script src="https://bnb.data.bl.uk/sites/all/themes/britishlibrary/js/script.js?pvz0k7"></script>\n<script>jQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"britishlibrary","theme_token":"omkFTZXk2djuf_LCBdB09g2tro3SIj3P0TF5bnEb26E","js":{"sites\\/all\\/modules\\/jquery_update\\/replace\\/jquery\\/1.5\\/jquery.min.js":1,"misc\\/jquery-extend-3.4.0.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"misc\\/ui\\/jquery.ui.core.min.js":1,"misc\\/ui\\/jquery.ui.widget.min.js":1,"misc\\/ui\\/jquery.ui.position.min.js":1,"misc\\/ui\\/jquery.ui.autocomplete.min.js":1,"sites\\/all\\/themes\\/britishlibrary\\/js\\/solr-search.js":1,"sites\\/all\\/themes\\/britishlibrary\\/js\\/script.js":1},"css":{"modules\\/system\\/system.base.css":1,"modules\\/system\\/system.menus.css":1,"modules\\/system\\/system.messages.css":1,"modules\\/system\\/system.theme.css":1,"misc\\/ui\\/jquery.ui.core.css":1,"misc\\/ui\\/jquery.ui.theme.css" ...
